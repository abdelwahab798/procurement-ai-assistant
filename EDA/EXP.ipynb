# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\nice\Desktop\BBI\procurement-ai-assistant\data\Sample_Purchase_Requests.csv")

# %%
df
# Out:
#            PR_ID    Requester   Department         Category  Amount_AED  \
# 0   PR-2026-0001   Dina Fathy  Procurement         Software       16849
# 1   PR-2026-0002  Salma Nabil   Operations         Hardware       29062
# 2   PR-2026-0003   Dina Fathy           HR         Hardware      305544
# 3   PR-2026-0004  Mariam Adel   Operations   Cloud Services       60986
# 4   PR-2026-0005  Salma Nabil    Marketing   Cloud Services      179176
# ..           ...          ...          ...              ...         ...
# 75  PR-2026-0076  Youssef Ali      Finance         Training      195957
# 76  PR-2026-0077   Omar Samir      Finance   Cloud Services       12909
# 77  PR-2026-0078   Omar Samir           HR       Consulting      190860
# 78  PR-2026-0079  Mariam Adel      Finance  Office Supplies       47319
# 79  PR-2026-0080   Omar Samir    Marketing      Maintenance      300236
#
#              Supplier_Selected Vendor_ID  \
# 0          Future Hardware Co.  VEN-1403
# ...

# %%
name=input("please enter your name")
df1=df.loc[df["Requester"]==name]
df1
b=sorted(df1["PR_ID"].unique().tolist())
print(b)
# Out:
# ['PR-2026-0001', 'PR-2026-0003', 'PR-2026-0007', 'PR-2026-0017', 'PR-2026-0018', 'PR-2026-0020', 'PR-2026-0027', 'PR-2026-0032', 'PR-2026-0033', 'PR-2026-0046', 'PR-2026-0056', 'PR-2026-0057', 'PR-2026-0059', 'PR-2026-0061', 'PR-2026-0071']

# %%
df["Requester"].unique()
# Out:
# array(['Dina Fathy', 'Salma Nabil', 'Mariam Adel', 'Omar Samir',
#        'Karim Hassan', 'Youssef Ali'], dtype=object)

# %%
df["PR_ID"]
# Out:
# 0     PR-2026-0001
# 1     PR-2026-0002
# 2     PR-2026-0003
# 3     PR-2026-0004
# 4     PR-2026-0005
#           ...
# 75    PR-2026-0076
# 76    PR-2026-0077
# 77    PR-2026-0078
# 78    PR-2026-0079
# 79    PR-2026-0080
# Name: PR_ID, Length: 80, dtype: object
